# %% [markdown]
# # Training and Validation of Binary VGG

# %%
for file in listfiles:
    temp = pd.read_csv(dirpath + file)
    temp.plot(x="epoch", y=["loss", "valid_loss"], title=file.replace(".csv", ""))

# %% [markdown]
# **Kesimpulan**: Berdasar terhadap loss dan validation loss, VGG13 merupakan model pembelajaran mesin yang paling optimal.
